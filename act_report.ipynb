# %% [markdown]
# # Analyzing WeRateDogs' Twitter Account

# %% [markdown]
# Everyone loves dogs, that's why WeRateDogs was made, to rate the cutest little dogs in existense.
#
# We analyzed their Twitter data and here's what we found out.

# %% [markdown]
# We analyzed all dog images with a neural network and got the amount of likes and retweets for each post.

# %% [markdown]
# This is the dog that Twitter users like most:
# ![cute puppo](https://pbs.twimg.com/media/C2tugXLXgAArJO4.jpg)

# %% [markdown]
# I honestly can't disagree with them on that one.. This is the labrador retriever, the second guess of our neural network.
#
# Let's see the highest rated dog..

# %% [markdown]
# Here's the highest rated dog from WeRateDogs:
# ![cute dog](https://pbs.twimg.com/media/CurzvFTXgAA2_AP.jpg)

# %% [markdown]
# This one definetly deserves the high rating! Our neural network guessed pomeranian and that was correct!

# %% [markdown]
# You might be thinking about how WeRateDogs operates, we analyzed that aswell.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# WeRateDogs seems to operate mostly on their iPhone, which I didn't expect for such a big popular account honestly.

# %% [markdown]
# ```bash
# timestamp
# 0     222
# 1     236
# 2     170
# 3     134
# 4      75
# 5      18
# 6       3
# 13      1
# 14      4
# 15     76
# 16    166
# 17    142
# 18     81
# 19     68
# 20     62
# 21     57
# 22     55
# 23     96
# Name: count, dtype: int64
# ```

# %% [markdown]
# WeRateDogs posts normally from 3PM-4AM which means they are sleeping for about 9 hours or so.
